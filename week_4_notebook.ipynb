# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# **Tom Nguyen**
# Data Scientist

# %% [markdown]
# *I am interested in data science because data science job is sexy :)*

# %% [markdown]
# Cell 5 will do this calculation: 1 + 1 = 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# ---
# This is a list:
# \* One
# \* Two
# \* Three
# This is a [link](https://www.markdownguide.org/basic-syntax/#links)
# ---
